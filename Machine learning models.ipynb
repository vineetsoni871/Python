# %%
# Machine Learning Models

# %%
# Data ----> x , y
# x ----> x_train , x_test
# y ----> y_train , y_test

# for model training
# model.fit(x_train , y_train)

# for model prediction
# y_pred = model.predict(x_test)

# Model Accuracy
# metrics_score(y_test , y_pred)

# %%
# Models ----->
# 1) Supervised ML Model ----> Labelled data train ----> LinearRegression , LogisticRegression , 
        # Decision tree , RandomForest etc
# 2) Umsupervised ML Model ----> Unlabelled data train ----> Kmeans , PCA

# %% [markdown]
# # LinearRegression

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Pandas\\insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['sex'] = lb.fit_transform(df['sex'])
df['smoker'] = lb.fit_transform(df['smoker'])
df['region'] = lb.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
x = df.drop(columns = ['charges'])
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,
                                                      random_state = 42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.7833463107364539
