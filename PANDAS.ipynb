# %% [markdown]
# # Pandas:
# Pandas is an open source library that is used for handling data manipulations.

# %%
# for installing pandas in jupyter or colab
# !pip install pandas

# for installing pandas in vs code
# pip install pandas

# %% [markdown]
# # Data structure of pandas:
# 1) Series: It is one dimensional array and it shows only values not column name.
# 2) Dataframe: It is multi-dimensional array and it shows values with column name.

# %% [markdown]
# # 1) Series:

# %%
import pandas as pd

# %%
a = pd.Series([1,34,67,90])
a
# Out:
# 0     1
# 1    34
# 2    67
# 3    90
# dtype: int64

# %%
type(a)
# Out:
# pandas.core.series.Series

# %% [markdown]
# # 2) DataFrame:

# %% [markdown]
# # Q1. We have to create employee data using dictionary?

# %%
a = {
    "Emp_ID":[1,2,3,4,5,6,7,8],
    "Emp_Name":['sam' , 'Raj','Mohit','Bharat','Anmol','Guru','Prakul','Anshul'],
    "Working_hours":[4,5,6,7,8,4,5,4],
    "salary":[20000,30000,40000,50000,30500,31000,32000,40000]
}

# %%
type(a)
# Out:
# dict

# %%
df = pd.DataFrame(a)
df
# Out:
#    Emp_ID Emp_Name  Working_hours  salary
# 0       1      sam              4   20000
# 1       2      Raj              5   30000
# 2       3    Mohit              6   40000
# 3       4   Bharat              7   50000
# 4       5    Anmol              8   30500
# 5       6     Guru              4   31000
# 6       7   Prakul              5   32000
# 7       8   Anshul              4   40000

# %% [markdown]
# # How do you export our dataframe into CSV file?

# %%
df.to_csv("C:\\Pandas\\emp_info.csv", index=False)

# %% [markdown]
# # How to import our dataframe into jupyter notebook ?

# %%
# Open a folder in which you have datasets

# copy the folder location

# Paste it into jupyter notebook

# df = pd.read_csv("paste_folder_location\\file_name.csv")

# %% [markdown]
# # Method-1

# %%
df = pd.read_csv("C:\\Pandas\\emp_info.csv")

# %%
df
# Out:
#    Emp_ID Emp_Name  Working_hours  salary
# 0       1      sam              4   20000
# 1       2      Raj              5   30000
# 2       3    Mohit              6   40000
# 3       4   Bharat              7   50000
# 4       5    Anmol              8   30500
# 5       6     Guru              4   31000
# 6       7   Prakul              5   32000
# 7       8   Anshul              4   40000

# %% [markdown]
# # Method-2

# %%
# Go to home page of jupyter

# Click on upload

# Click in open --> upload.

# pd.read_csv("filename.csv")

# %%
student_data = {
    "ID": [101, 102, 103, 104, 105, 106, 107, 108, 109, 110],
    "Name": ["Aman", "Priya", "Raj", "Simran", "Vikram", "Neha", "Rohit", "Ananya", "Kunal", "Isha"],
    "Roll No": [2101, 2102, 2103, 2104, 2105, 2106, 2107, 2108, 2109, 2110],
    "Stream": ["Science", "Commerce", "Arts", "Science", "Commerce", "Arts", "Science", "Commerce", "Arts", "Science"],
    "Semester": [2, 4, 6, 3, 5, 1, 4, 2, 6, 3]
}

# %%
type(student_data)
# Out:
# dict

# %%
a= pd.DataFrame(student_data)
a
# Out:
#     ID    Name  Roll No    Stream  Semester
# 0  101    Aman     2101   Science         2
# 1  102   Priya     2102  Commerce         4
# 2  103     Raj     2103      Arts         6
# 3  104  Simran     2104   Science         3
# 4  105  Vikram     2105  Commerce         5
# 5  106    Neha     2106      Arts         1
# 6  107   Rohit     2107   Science         4
# 7  108  Ananya     2108  Commerce         2
# 8  109   Kunal     2109      Arts         6
# 9  110    Isha     2110   Science         3

# %%
a.to_csv("C:\\Pandas\\student_info.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 a.to_csv("C:\\Pandas\\student_info.csv")
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Pandas\\covid_toy.csv")
df
# Out:
#     age  gender  fever   cough       city has_covid
# 0    60    Male  103.0    Mild    Kolkata        No
# 1    27    Male  100.0    Mild      Delhi       Yes
# 2    42    Male  101.0    Mild      Delhi        No
# 3    31  Female   98.0    Mild    Kolkata        No
# 4    65  Female  101.0    Mild     Mumbai        No
# ..  ...     ...    ...     ...        ...       ...
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes
#
# [100 rows x 6 columns]

# %%
df.shape  # rows , columns
# Out:
# (100, 6)

# %%
df.size   # row*columns
# Out:
# 600

# %%
df.columns    #$ It will return the column name
# Out:
# Index(['age', 'gender', 'fever', 'cough', 'city', 'has_covid'], dtype='object')

# %%
# If you want to find the top dataframe then you can use head()

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.head(3)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes
# 2   42   Male  101.0  Mild    Delhi        No

# %%
# If you want to find the last data from dataframe

# %%
df.tail()
# Out:
#     age  gender  fever   cough       city has_covid
# 95   12  Female  104.0    Mild  Bangalore        No
# 96   51  Female  101.0  Strong    Kolkata       Yes
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
df.tail(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 97   20  Female  101.0    Mild  Bangalore        No
# 98    5  Female   98.0  Strong     Mumbai        No
# 99   10  Female   98.0  Strong    Kolkata       Yes

# %%
# If you want to find randomly indexed data then

# %%
df.sample(3)
# Out:
#     age  gender  fever   cough       city has_covid
# 44   20    Male  102.0  Strong      Delhi        No
# 36   38  Female  101.0    Mild  Bangalore        No
# 5    84  Female    NaN    Mild  Bangalore       Yes

# %%
### Specific elements:

# %%
## Loc method [row_range , column_name]
df.loc[3:5, ['age' , 'has_covid']]
# Out:
#    age has_covid
# 3   31        No
# 4   65        No
# 5   84       Yes

# %%
## iloc method [row_range , column_range]
df.iloc[3:6 , [0,1,3]]
# Out:
#    age  gender cough
# 3   31  Female  Mild
# 4   65  Female  Mild
# 5   84  Female  Mild

# %% [markdown]
# # DataFrame is mutuable

# %%
df.head(4)
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No

# %%
df['has_covid'][2]
# Out:
# 'No'

# %%
df['has_covid'][2] = 'Yes'
# Out:
# C:\Users\vinee\AppData\Local\Temp\ipykernel_11076\1005488291.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df['has_covid'][2] = 'Yes'
# ...

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi       Yes
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
## specific row , column ----> loc , iloc
### specific column ----> data ----> df['column_name'][indexing]

# %%
#df['gender'][2:5]

# %% [markdown]
# # If you want to check overall information then

# %%
# df.indo()

# %% [markdown]
# # If you want to check statistically view of data then you can use

# %%
df.describe()
# Out:
#               age       fever
# count  100.000000   90.000000
# mean    44.220000  100.844444
# std     24.878931    2.054926
# min      5.000000   98.000000
# 25%     20.000000   99.000000
# 50%     45.000000  101.000000
# 75%     66.500000  102.750000
# max     84.000000  104.000000

# %% [markdown]
# # If you want to check how many elements are available in a particular column

# %%
# df.head(4)

# %%
df['has_covid'].value_counts()
# Out:
# has_covid
# No     54
# Yes    46
# Name: count, dtype: int64

# %%
# df['gender'].value_counts()

# %%
# df['cough'].value_counts()

# %%
# Data:

# 1) Numerical ---> continuous data----> divided further ----> DOB(23years 6 months 20 days) , salary(12220.45)

# 2) Categorical ---> Describe data ---> total students in class , marital status.

# %%
# Google ----> extension (Instant data scrapper) ---> Add extension --->

# Flipkart ---> Product scrap()

# %%
df = pd.read_csv("C:\\Users\\vinee\\Downloads\\flipkart.csv")

# %%
import pandas as pd

# %%
df
# Out:
#                                           rPDeLR href  \
# 0   https://www.flipkart.com/avolt-solid-men-grey-...
# 1   https://www.flipkart.com/yazole-solid-men-blac...
# 2   https://www.flipkart.com/hrx-hrithik-roshan-so...
# 3   https://www.flipkart.com/vebnor-printed-men-bl...
# 4   https://www.flipkart.com/avolt-striped-men-mul...
# 5   https://www.flipkart.com/crease-clips-printed-...
# 6   https://www.flipkart.com/highlander-solid-men-...
# 7   https://www.flipkart.com/vebnor-solid-men-dark...
# 8   https://www.flipkart.com/alan-jones-solid-men-...
# 9   https://www.flipkart.com/dida-solid-men-black-...
# 10                                                NaN
# 11                                                NaN
#
#                                           _53J4C- src                 syl9yP  \
# 0   https://rukminim2.flixcart.com/image/612/612/x...                  AVOLT
# 1   https://rukminim2.flixcart.com/image/612/612/x...                 Yazole
# ...

# %%
df.head(2)
# Out:
#                                          rPDeLR href  \
# 0  https://www.flipkart.com/avolt-solid-men-grey-...
# 1  https://www.flipkart.com/yazole-solid-men-blac...
#
#                                          _53J4C- src  syl9yP  \
# 0  https://rukminim2.flixcart.com/image/612/612/x...   AVOLT
# 1  https://rukminim2.flixcart.com/image/612/612/x...  Yazole
#
#                                         WKTcLC  \
# 0         Pack of 2 Men Solid Grey Track Pants
# 1  Pack of 2 Men Solid Black, Grey Track Pants
#
#                                          WKTcLC href  \
# 0  https://www.flipkart.com/avolt-solid-men-grey-...
# 1  https://www.flipkart.com/yazole-solid-men-blac...
#
#                                           iW2uHd src Nx9bqj  yRaY8j   UkUFwK  \
# 0  https://static-assets-web.flixcart.com/fk-p-li...   ₹399  ₹2,999  86% off
# 1  https://static-assets-web.flixcart.com/fk-p-li...   ₹379  ₹2,499  84% off
#
#           yiggsN  ...       yiggsN 6  \
# ...

# %%
df.tail(3)
# Out:
#                                           rPDeLR href  \
# 9   https://www.flipkart.com/dida-solid-men-black-...
# 10                                                NaN
# 11                                                NaN
#
#                                           _53J4C- src syl9yP  \
# 9   https://rukminim2.flixcart.com/image/612/612/x...   DIDA
# 10                                                NaN    NaN
# 11                                                NaN    NaN
#
#                          WKTcLC  \
# 9   Men Solid Black Track Pants
# 10                          NaN
# 11                          NaN
#
#                                           WKTcLC href  \
# 9   https://www.flipkart.com/hrx-hrithik-roshan-so...
# 10                                                NaN
# 11                                                NaN
#
#                                            iW2uHd src Nx9bqj  yRaY8j   UkUFwK  \
# ...

# %%
df.sample(2)
# Out:
#                                          rPDeLR href  \
# 4  https://www.flipkart.com/avolt-striped-men-mul...
# 3  https://www.flipkart.com/vebnor-printed-men-bl...
#
#                                          _53J4C- src  syl9yP  \
# 4  https://rukminim2.flixcart.com/image/612/612/x...   AVOLT
# 3  https://rukminim2.flixcart.com/image/612/612/x...  VeBNoR
#
#                                               WKTcLC  \
# 4  Pack of 2 Men Self Design Blue, Black Track Pants
# 3     Pack of 2 Men Printed Black, Green Track Pants
#
#                                          WKTcLC href  \
# 4  https://www.flipkart.com/yazole-self-design-me...
# 3  https://www.flipkart.com/vebnor-printed-men-bl...
#
#                                           iW2uHd src Nx9bqj  yRaY8j   UkUFwK  \
# 4  https://static-assets-web.flixcart.com/fk-p-li...   ₹399  ₹2,999  86% off
# 3  https://static-assets-web.flixcart.com/fk-p-li...   ₹349    ₹999  65% off
#
#           yiggsN  ...       yiggsN 6  \
# ...

# %%
df.describe()
# Out:
#                                               rPDeLR href  \
# count                                                  10
# unique                                                 10
# top     https://www.flipkart.com/avolt-solid-men-grey-...
# freq                                                    1
#
#                                               _53J4C- src syl9yP  \
# count                                                  10     10
# unique                                                 10      8
# top     https://rukminim2.flixcart.com/image/612/612/x...  AVOLT
# freq                                                    1      2
#
#                              WKTcLC  \
# count                            10
# unique                            9
# top     Men Solid Black Track Pants
# freq                              2
#
#                                               WKTcLC href  \
# count                                                  10
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 39 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   rPDeLR href    10 non-null     object
#  1   _53J4C- src    10 non-null     object
#  2   syl9yP         10 non-null     object
#  3   WKTcLC         10 non-null     object
#  4   WKTcLC href    10 non-null     object
#  5   iW2uHd src     10 non-null     object
#  6   Nx9bqj         10 non-null     object
#  7   yRaY8j         10 non-null     object
#  8   UkUFwK         10 non-null     object
#  9   yiggsN         10 non-null     object
#  10  yiggsN 2       10 non-null     object
#  11  rPDeLR href 2  10 non-null     object
#  12  _53J4C- src 2  10 non-null     object
#  13  syl9yP 2       10 non-null     object
#  14  WKTcLC 2       10 non-null     object
#  15  WKTcLC href 2  10 non-null     object
#  16  iW2uHd src 2   7 non-null      object
# ...

# %%
df.iloc[3:6 , [0,1,3]]
# Out:
#                                          rPDeLR href  \
# 3  https://www.flipkart.com/vebnor-printed-men-bl...
# 4  https://www.flipkart.com/avolt-striped-men-mul...
# 5  https://www.flipkart.com/crease-clips-printed-...
#
#                                          _53J4C- src  \
# 3  https://rukminim2.flixcart.com/image/612/612/x...
# 4  https://rukminim2.flixcart.com/image/612/612/x...
# 5  https://rukminim2.flixcart.com/image/612/612/x...
#
#                                               WKTcLC
# 3     Pack of 2 Men Printed Black, Green Track Pants
# 4  Pack of 2 Men Self Design Blue, Black Track Pants
# 5       Pack of 2 Men Solid Silver, Grey Track Pants

# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Pandas\\placement.csv")
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 26  6.27          6.47       0

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
top_left_corner_df = df.iloc[:4 , :3]  # iloc[row_range , column_range]
top_left_corner_df
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='object')]

# %%
b = df.empty  # it returns true if there any missing data in DataFrame otherwise return false
b
# Out:
# False

# %%
df.isnull().sum()   # For checking missing vakues
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.dropna()  ## For removing missing values
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
i = df.ndim  # No. of axes (it is 2)
i
# Out:
# 2

# %%
t = df.shape  # Shape = n(rows) , n(columns)
t
# Out:
# (100, 3)

# %%
d = df.size  # row count * column count
d
# Out:
# 300

# %%
a = df.values    # get a numpy array for df
a
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
r = df.sort_index()
r
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
# x = df.astype(int)   # type converion
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
t = df.add(4)
t
df['cgpa'] = df['cgpa'].add(4)

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
p = df.max()
p
# Out:
# cgpa            17.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
q = df.min()
q
# Out:
# cgpa            13.00
# resume_score     4.95
# placed           0.00
# dtype: float64

# %%
r = df['cgpa'].mean()
r
# Out:
# np.float64(14.47)

# %%
s = df['cgpa'].median()
s
# Out:
# np.float64(14.0)

# %%
s = df.sum()
s
# Out:
# cgpa            1447.00
# resume_score     693.05
# placed            50.00
# dtype: float64

# %%
g = df.filter(items = ['cgpa' , 'placed'])
g

df[['cgpa' , 'placed']]   ## second option for filtering
# Out:
#     cgpa  placed
# 0     16       1
# 1     14       0
# 2     16       1
# 3     14       1
# 4     15       1
# ..   ...     ...
# 95    14       0
# 96    16       1
# 97    14       0
# 98    16       1
# 99    14       0
#
# [100 rows x 2 columns]

# %%
# axes = 0 means row wise operation
# axes = 1 means column wise operation

# %%
df.columns
# Out:
# Index(['cgpa', 'resume_score', 'placed'], dtype='object')

# %%
df.values
# Out:
# array([[16.  ,  6.52,  1.  ],
#        [14.  ,  5.17,  0.  ],
#        [16.  ,  8.86,  1.  ],
#        [14.  ,  7.27,  1.  ],
#        [15.  ,  7.3 ,  1.  ],
#        [16.  ,  6.19,  1.  ],
#        [13.  ,  7.09,  0.  ],
#        [14.  ,  6.29,  0.  ],
#        [14.  ,  6.71,  0.  ],
#        [15.  ,  7.12,  1.  ],
#        [14.  ,  6.35,  0.  ],
#        [13.  ,  6.54,  0.  ],
#        [14.  ,  7.01,  0.  ],
#        [16.  ,  5.09,  1.  ],
#        [15.  ,  6.25,  1.  ],
#        [16.  ,  5.93,  1.  ],
#        [16.  ,  7.64,  1.  ],
#        [15.  ,  8.71,  1.  ],
#        [13.  ,  5.88,  0.  ],
#        [14.  ,  8.11,  1.  ],
#        [13.  ,  8.06,  0.  ],
#        [14.  ,  7.64,  0.  ],
#        [14.  ,  5.77,  0.  ],
#        [14.  ,  7.13,  0.  ],
#        [16.  ,  6.18,  1.  ],
#        [15.  ,  5.68,  1.  ],
#        [14.  ,  6.47,  0.  ],
#        [13.  ,  6.15,  0.  ],
#        [15.  ,  7.67,  1.  ],
#        [14.  ,  7.3 ,  0.  ],
#        [15.  ,  7.15,  1.  ],
# ...

# %%
new_df = pd.DataFrame(df.values , columns = df.columns)
new_df
# Out:
#     cgpa  resume_score  placed
# 0   16.0          6.52     1.0
# 1   14.0          5.17     0.0
# 2   16.0          8.86     1.0
# 3   14.0          7.27     1.0
# 4   15.0          7.30     1.0
# ..   ...           ...     ...
# 95  14.0          6.38     0.0
# 96  16.0          7.76     1.0
# 97  14.0          7.78     0.0
# 98  16.0          5.63     1.0
# 99  14.0          6.61     0.0
#
# [100 rows x 3 columns]

# %%
df.head(3)
# Out:
#    cgpa  resume_score  placed
# 0    16          6.52       1
# 1    14          5.17       0
# 2    16          8.86       1

# %%
p = df.columns.tolist()   # List of column lables
p
# Out:
# ['cgpa', 'resume_score', 'placed']

# %%
q = df.columns.values    # rray of column labels
q
# Out:
# array(['cgpa', 'resume_score', 'placed'], dtype=object)

# %%
p = df.rename(columns = {'cgpa':'updated_cgpa' , 
                        'resume_score':'semester_marks'})  # How to rename a column
p
# Out:
#     updated_cgpa  semester_marks  placed
# 0             16            6.52       1
# 1             14            5.17       0
# 2             16            8.86       1
# 3             14            7.27       1
# 4             15            7.30       1
# ..           ...             ...     ...
# 95            14            6.38       0
# 96            16            7.76       1
# 97            14            7.78       0
# 98            16            5.63       1
# 99            14            6.61       0
#
# [100 rows x 3 columns]
